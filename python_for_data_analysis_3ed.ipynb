# %% [markdown]
# # Import Conventions
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# import seaborn as sns
# import statsmodels as sm

# %% [markdown]
# # NumPy
# NumPy short for Numerical Python, is one of the most important foundational packages for numerical computing in Python.
# Many computational packages providing scientific functionality use NumPy’s array objects as one of the standard interface lingua francas for data exchange.

# %%
import numpy as np

# %% [markdown]
# ## N-dimensional array
# All of the elements must be the same type.

# %%
data = np.array([[1.5, -0.1, 3], [0, -3, 6.5]])

# %%
data
# Out:
# array([[ 1.5, -0.1,  3. ],
#        [ 0. , -3. ,  6.5]])

# %%
data * 10
# Out:
# array([[ 15.,  -1.,  30.],
#        [  0., -30.,  65.]])

# %%
data + data
# Out:
# array([[ 3. , -0.2,  6. ],
#        [ 0. , -6. , 13. ]])

# %%
data.shape
# Out:
# (2, 3)

# %%
data.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Creating ndarray from a list.

# %%
data_list = [[1, 2, 3, 4], [5, 6, 7, 8]]

# %%
arr = np.array(data_list)

# %%
arr.ndim
# Out:
# 2

# %%
arr.shape
# Out:
# (2, 4)

# %%
arr.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Functions to create new arrays

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
np.zeros((3, 2))
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
np.empty((2, 3, 2))
# Out:
# array([[[5.47383008e-310, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000],
#         [6.88460314e-310, 3.92738306e-033]],
#
#        [[1.04876599e-042, 7.25341356e+169],
#         [1.13827268e-042, 3.54162782e-061],
#         [1.53324168e-075, 3.83623950e+175]]])

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
arr1 = np.array([1, 2, 3], dtype=np.float64)

# %%
arr1.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Explicitly convert or cast an array from one data type to another using ndarray’s astype method

# %%
arr_int = np.array([1, 2, 3], dtype=np.int32)

# %%
arr_int.dtype
# Out:
# dtype('int32')

# %%
arr_float = arr_int.astype(np.float64)

# %%
arr_float.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series

# %%
obj = pd.Series([4, 5, -7, 3])
obj
# Out:
# 0    4
# 1    5
# 2   -7
# 3    3
# dtype: int64

# %%
obj[2]
# Out:
# np.int64(-7)

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [np.int64(4), np.int64(5), np.int64(-7), np.int64(3)]
# Length: 4, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([4, 7, -5, 3], index=["d", "b", "a", "c"])

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2['a']
# Out:
# np.int64(-5)

# %%
obj2[['d', 'b']]
# Out:
# d    4
# b    7
# dtype: int64

# %%
obj2[:2]
# Out:
# d    4
# b    7
# dtype: int64

# %%
obj >= 3
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
obj2[obj2 >= 3]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
np.exp2(obj2)
# Out:
# d     16.00000
# b    128.00000
# a      0.03125
# c      8.00000
# dtype: float64

# %%
'b' in obj2
# Out:
# True

# %% [markdown]
# ### Create Series from a dict

# %%
sdata = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}

# %%
obj3 = pd.Series(sdata)

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj3.to_dict()
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %% [markdown]
# ### Respecting a order

# %%
states = ["California", "Ohio", "Oregon", "Texas"]

# %%
obj4 = pd.Series(sdata, index=states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isna(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notna(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj4.notna()
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %% [markdown]
# ### Automatically aligns by index label in arithmetics operations

# %%
obj3 + obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
obj4.name = 'population_name'

# %%
obj4.index.name = 'states_index'

# %%
obj4
# Out:
# states_index
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population_name, dtype: float64

# %%
obj
# Out:
# 0    4
# 1    5
# 2   -7
# 3    3
# dtype: int64

# %%
obj.index = ['a', 'b', 'c', 'd']

# %%
obj
# Out:
# a    4
# b    5
# c   -7
# d    3
# dtype: int64

# %% [markdown]
# # DataFrame

# %%
data = {
    "state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada","Nevada"],
    "year": [2000, 2001, 2002, 2001, 2002, 2003],
    "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
}

# %%
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# ### Selecting and ordering

# %%
frame2 = pd.DataFrame(data, columns=['pop', 'year', 'asdf'])
frame2
# Out:
#    pop  year asdf
# 0  1.5  2000  NaN
# 1  1.7  2001  NaN
# 2  3.6  2002  NaN
# 3  2.4  2001  NaN
# 4  2.9  2002  NaN
# 5  3.2  2003  NaN

# %%
frame2.columns
# Out:
# Index(['pop', 'year', 'asdf'], dtype='object')

# %%
frame2['year']
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
frame2
# Out:
#    pop  year asdf
# 0  1.5  2000  NaN
# 1  1.7  2001  NaN
# 2  3.6  2002  NaN
# 3  2.4  2001  NaN
# 4  2.9  2002  NaN
# 5  3.2  2003  NaN

# %%
frame2.iloc[1]
# Out:
# pop      1.7
# year    2001
# asdf     NaN
# Name: 1, dtype: object

# %%
frame2.asdf = 123

# %%
frame2
# Out:
#    pop  year  asdf
# 0  1.5  2000   123
# 1  1.7  2001   123
# 2  3.6  2002   123
# 3  2.4  2001   123
# 4  2.9  2002   123
# 5  3.2  2003   123

# %%
frame2.asdf = np.arange(6.)

# %%
frame2
# Out:
#    pop  year  asdf
# 0  1.5  2000   0.0
# 1  1.7  2001   1.0
# 2  3.6  2002   2.0
# 3  2.4  2001   3.0
# 4  2.9  2002   4.0
# 5  3.2  2003   5.0

# %%
frame2['date_choosed'] = frame2['year'] == 2002

# %%
frame2
# Out:
#    pop  year  asdf  date_choosed
# 0  1.5  2000   0.0         False
# 1  1.7  2001   1.0         False
# 2  3.6  2002   2.0          True
# 3  2.4  2001   3.0         False
# 4  2.9  2002   4.0          True
# 5  3.2  2003   5.0         False

# %%
del frame2['date_choosed']

# %%
frame2
# Out:
#    pop  year  asdf
# 0  1.5  2000   0.0
# 1  1.7  2001   1.0
# 2  3.6  2002   2.0
# 3  2.4  2001   3.0
# 4  2.9  2002   4.0
# 5  3.2  2003   5.0

# %% [markdown]
# ### Dictinoary of dictionary

# %%
populations = {
    "Ohio": {
        2000: 1.5, 2001: 1.7, 2002: 3.6
    },
    "Nevada": {
        2001: 2.4, 2002: 2.9
    }}

# %%
frame3 = pd.DataFrame(populations)

# %%
frame3
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %% [markdown]
# ### Swap rows and columns

# %%
frame3.T
# Out:
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9
