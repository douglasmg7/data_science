# %%
import pandas as pd

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon','Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})

# %%
df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
g = df.groupby(['Animal'])

# %%
type(g['Max Speed'].count())
# Out:
# pandas.core.series.Series

# %%
type(g.count())
# Out:
# pandas.core.frame.DataFrame
